# %% [markdown]
# # 4.7. TASK
# # Table of Contents
# ## 1. Exercise practice
# ### 1.1. Import libraries and data set
# ### 1.2. Practice user-defined functions
# ### 1.3. Create "price_label" row using user-defined function
# ### 1.4. Create "price_label" row using loc() function
# ### 1.5. Practice and create "busiest_day" row with for-loops
# ## 2. Extra data consistency and data wrangling checks
# ### 2.1. Replace wrong values in the "prices" column of the "df_prods" dataframe
# ### 2.2. Drop unwanted columns
# ### 2.3. Export clean "df_prods" dataframe
# ### 2.4. Replace wrong values in the "prices" column of the "ords_prods_merge" dataframe
# ### 2.5. Drop unwanted columns
# ## 3. Task
# ### 3.1. Change conditions of "busiest_day" column to "busiest_days"
# ### 3.2. Check accuracy of the new column
# ### 3.3. Create new column "busiest_period_of_day"
# ### 3.4. Show frequency of "busiest_period_of_day" columns
# ### 3.5. Export dataframe

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Exercise practice
# ### 1.1. Import libraries and data set

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/mariliamachado/Documents/CareerFoundry/11-2024 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
#
#    orders_day_of_week  order_time_hour  days_since_prior_order  first_order  \
# 0                   2                8                     NaN         True
# 1                   2                8                     NaN         True
# 2                   2                8                     NaN         True
# 3                   2                8                     NaN         True
# 4                   2                8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge  Unnamed: 0_y  \
# ...

# %% [markdown]
# ### 1.2. Practice user-defined functions

# %%
# define function
def add_num(x, y):
    sum = x + y
    return sum

# %%
# run function
add_num(9,11)
# Out:
# 20

# %%
#create subset
df = ords_prods_merge[:1000000]

# %% [markdown]
# ### 1.3. Create "price_label" row using user-defined function

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Run function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/1l/dnjb8fld07b4wz73yz4dyxqw0000gn/T/ipykernel_25488/1267003000.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    673340
# Low-range product    314392
# High range            12268
# Name: count, dtype: int64

# %%
# check most expensive product
df['prices'].max()
# Out:
# 25.0

# %% [markdown]
# ### 1.4. Create "price_label" row using loc() function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product' 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     673340
# Low-range product     314392
# High-range product     12268
# Name: count, dtype: int64

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product' 
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %% [markdown]
# ### 1.5. Practice and create "busiest_day" row with for-loops

# %%
for x in range (30, 45):
    print('My age is %d' % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []
for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
#
#    orders_day_of_week  order_time_hour  days_since_prior_order  first_order  \
# 0                   2                8                     NaN         True
# 1                   2                8                     NaN         True
# 2                   2                8                     NaN         True
# 3                   2                8                     NaN         True
# 4                   2                8                     NaN         True
#
#    product_id  ...  reordered  _merge Unnamed: 0_y  \
# 0         196  ...          0    both          195
# ...

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
#
#    orders_day_of_week  order_time_hour  days_since_prior_order  first_order  \
# 0                   2                8                     NaN         True
# 1                   2                8                     NaN         True
# 2                   2                8                     NaN         True
# 3                   2                8                     NaN         True
# 4                   2                8                     NaN         True
#
#    product_id  ...  reordered  _merge Unnamed: 0_y  \
# 0         196  ...          0    both          195
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 15)

# %%
# check most expensive product
ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# ## 2. Extra data consistency and data wrangling checks

# %%
# Check possible wrong max value 
max_price = ords_prods_merge['prices'].max()

# %%
# Filter rows with wrong max value
rows_max_value = ords_prods_merge [ords_prods_merge['prices'] == max_price]

# %%
rows_max_value
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 128911           13992         13992    183964      873             3
# 128924           13993         13993   1851256      873             4
# 284218           30778         30778   1915696     1893             1
# 284229           30779         30779   2763293     1893             2
# 284252           30781         30781   2564805     1893             4
# ...                ...           ...       ...      ...           ...
# 32079919       3386542       3386542   2249946   204099            29
# 32079936       3386544       3386544   2363282   204099            31
# 32125745       3391313       3391313   3181945   204395            13
# 32255078       3405096       3405096   2486215   205227             7
# 32255132       3405099       3405099   2232716   205227            10
#
#           orders_day_of_week  order_time_hour  days_since_prior_order  \
# ...

# %%
#Import products dataset to check wrong max value
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %%
#Check max value in prices 
prods_max_price = df_prods['prices'].max()
prods_rows_max_value = df_prods [df_prods['prices'] == prods_max_price]

# %%
prods_rows_max_value
# Out:
#        Unnamed: 0  product_id           product_name  aisle_id  department_id  \
# 33649       33666       33664  2 % Reduced Fat  Milk        84             16
#
#         prices
# 33649  99999.0

# %%
#Check product name with similar name to see price
df_prods.loc[df_prods ['product_name'] == '2% Reduced Fat Milk']
# Out:
#        Unnamed: 0  product_id         product_name  aisle_id  department_id  \
# 23894       23910       23909  2% Reduced Fat Milk        84             16
#
#        prices
# 23894     9.2

# %%
wrong_values = df_prods.loc[df_prods ['product_id'] == 33664]

# %%
wrong_values
# Out:
#        Unnamed: 0  product_id           product_name  aisle_id  department_id  \
# 33649       33666       33664  2 % Reduced Fat  Milk        84             16
#
#         prices
# 33649  99999.0

# %% [markdown]
# ### 2.1. Replace wrong values in the "prices" column of the "df_prods" dataframe

# %%
#replace wrong values with test df
wrong_values.loc[33649, 'prices'] = 9.2

# %%
#check if it worked
wrong_values
# Out:
#        Unnamed: 0  product_id           product_name  aisle_id  department_id  \
# 33649       33666       33664  2 % Reduced Fat  Milk        84             16
#
#        prices
# 33649     9.2

# %%
df_prods.loc[df_prods ['product_id'] == 33664]
# Out:
#        Unnamed: 0  product_id           product_name  aisle_id  department_id  \
# 33649       33666       33664  2 % Reduced Fat  Milk        84             16
#
#         prices
# 33649  99999.0

# %%
#replace wrong value on products df
df_prods.loc[33649, 'prices'] = 9.2

# %%
#check if it worked
df_prods.loc[df_prods ['product_id'] == 33664]
# Out:
#        Unnamed: 0  product_id           product_name  aisle_id  department_id  \
# 33649       33666       33664  2 % Reduced Fat  Milk        84             16
#
#        prices
# 33649     9.2

# %%
#check max price again
prods_max_price = df_prods['prices'].max()

# %%
prods_max_price
# Out:
# 14900.0

# %%
#check product with that max value, it seems too high
max_value = df_prods.loc[df_prods ['prices'] == 14900.0]

# %%
max_value
# Out:
#        Unnamed: 0  product_id                      product_name  aisle_id  \
# 21538       21554       21553  Lowfat 2% Milkfat Cottage Cheese       108
#
#        department_id   prices
# 21538             16  14900.0

# %%
#check similar product names to see if we can find the most accurate value
def search(df_prods: pd.DataFrame, substring: str, case: bool = False) -> pd.DataFrame:
    mask = np.column_stack([df_prods[col].astype(str).str.contains(substring.lower(), case=case, na=False) for col in df_prods])
    return df_prods.loc[mask.any(axis=1)]

# %%
search(df_prods, 'Milkfat Cottage Cheese')
# Out:
#        Unnamed: 0  product_id                                 product_name  \
# 6837         6852        6852   4% Milkfat Cottage Cheese Small Curd 22 OZ
# 21538       21554       21553             Lowfat 2% Milkfat Cottage Cheese
# 27775       27792       27790  Small Curd Lowfat 2% Milkfat Cottage Cheese
# 28647       28664       28662         Strawberry 2% Milkfat Cottage Cheese
#
#        aisle_id  department_id   prices
# 6837        108             16      8.6
# 21538       108             16  14900.0
# 27775       108             16      7.7
# 28647       100             21      3.0

# %%
#Check mean value of prices since we don't know the accurate value
df_prods['prices'].mean()
# Out:
# 7.980280641004993

# %%
#Replace wrong value with mean value
df_prods.loc[21538, 'prices'] = 8

# %%
#Check if it worked
df_prods.loc[df_prods ['product_id'] == 21553]
# Out:
#        Unnamed: 0  product_id                      product_name  aisle_id  \
# 21538       21554       21553  Lowfat 2% Milkfat Cottage Cheese       108
#
#        department_id  prices
# 21538             16     8.0

# %% [markdown]
# ### 2.2. Drop unwanted columns

# %%
#Drop unnamed column
df_prods.drop(['Unnamed: 0'], axis=1)
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods = df_prods.drop(['Unnamed: 0'], axis=1)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ### 2.3. Export clean "df_prods" dataframe

# %%
# Export new dataframe
df_prods.to_csv(os.path.join(path, '02 Data','Prepared Data', 'prods_clean.csv'))

# %%
ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %%
ords_prods_merge.loc[ords_prods_merge ['product_id'] == 33664]
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 128911           13992         13992    183964      873             3
# 128924           13993         13993   1851256      873             4
# 284218           30778         30778   1915696     1893             1
# 284229           30779         30779   2763293     1893             2
# 284252           30781         30781   2564805     1893             4
# ...                ...           ...       ...      ...           ...
# 32079919       3386542       3386542   2249946   204099            29
# 32079936       3386544       3386544   2363282   204099            31
# 32125745       3391313       3391313   3181945   204395            13
# 32255078       3405096       3405096   2486215   205227             7
# 32255132       3405099       3405099   2232716   205227            10
#
#           orders_day_of_week  order_time_hour  days_since_prior_order  \
# ...

# %% [markdown]
# ### 2.4. Replace wrong values in the "prices" column of the "ords_prods_merge" dataframe

# %%
#Test replacing values on test df
df_test_replace = ords_prods_merge.loc[ords_prods_merge['prices'] == 99999.0, 'prices'] = 9.2

# %%
#Check
df_test_replace
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 128911           13992         13992    183964      873             3
# 128924           13993         13993   1851256      873             4
# 284218           30778         30778   1915696     1893             1
# 284229           30779         30779   2763293     1893             2
# 284252           30781         30781   2564805     1893             4
# ...                ...           ...       ...      ...           ...
# 32079919       3386542       3386542   2249946   204099            29
# 32079936       3386544       3386544   2363282   204099            31
# 32125745       3391313       3391313   3181945   204395            13
# 32255078       3405096       3405096   2486215   205227             7
# 32255132       3405099       3405099   2232716   205227            10
#
#           orders_day_of_week  order_time_hour  days_since_prior_order  \
# ...

# %%
ords_prods_merge.loc[ords_prods_merge ['product_id'] == 33664]

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] == 99999.0, 'prices'] = 9.2

# %%
ords_prods_merge.loc[ords_prods_merge ['product_id'] == 33664]
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 128911           13992         13992    183964      873             3
# 128924           13993         13993   1851256      873             4
# 284218           30778         30778   1915696     1893             1
# 284229           30779         30779   2763293     1893             2
# 284252           30781         30781   2564805     1893             4
# ...                ...           ...       ...      ...           ...
# 32079919       3386542       3386542   2249946   204099            29
# 32079936       3386544       3386544   2363282   204099            31
# 32125745       3391313       3391313   3181945   204395            13
# 32255078       3405096       3405096   2486215   205227             7
# 32255132       3405099       3405099   2232716   205227            10
#
#           orders_day_of_week  order_time_hour  days_since_prior_order  \
# ...

# %%
#Locate second wrong value
second_wrong_value = ords_prods_merge.loc[ords_prods_merge ['product_id'] == 21553]

# %%
second_wrong_value
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 1576               171           171    912404       17            12
# 1638               181           181    603376       17            22
# 16522             1944          1944   3264360      135             2
# 16528             1945          1945    892534      135             3
# 53672             5708          5708    229704      342             8
# ...                ...           ...       ...      ...           ...
# 32320511       3411856       3411856   3172853   205650            18
# 32347717       3414691       3414691   2504315   205818             3
# 32347727       3414693       3414693   1108388   205818             5
# 32380527       3418470       3418470   1916142   206049             1
# 32380551       3418473       3418473    379732   206049             4
#
#           orders_day_of_week  order_time_hour  days_since_prior_order  \
# ...

# %%
#Replace wrong value on test df
second_wrong_value.loc[second_wrong_value['prices'] == 14900.0, 'prices'] = 8

# %%
#Check if it worked
second_wrong_value
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 1576               171           171    912404       17            12
# 1638               181           181    603376       17            22
# 16522             1944          1944   3264360      135             2
# 16528             1945          1945    892534      135             3
# 53672             5708          5708    229704      342             8
# ...                ...           ...       ...      ...           ...
# 32320511       3411856       3411856   3172853   205650            18
# 32347717       3414691       3414691   2504315   205818             3
# 32347727       3414693       3414693   1108388   205818             5
# 32380527       3418470       3418470   1916142   206049             1
# 32380551       3418473       3418473    379732   206049             4
#
#           orders_day_of_week  order_time_hour  days_since_prior_order  \
# ...

# %%
#Replace wrong value on actual df
ords_prods_merge.loc[ords_prods_merge['prices'] == 14900.0, 'prices'] = 8

# %%
#Check values
ords_prods_merge.loc[ords_prods_merge ['product_id'] == 21553]
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 1576               171           171    912404       17            12
# 1638               181           181    603376       17            22
# 16522             1944          1944   3264360      135             2
# 16528             1945          1945    892534      135             3
# 53672             5708          5708    229704      342             8
# ...                ...           ...       ...      ...           ...
# 32320511       3411856       3411856   3172853   205650            18
# 32347717       3414691       3414691   2504315   205818             3
# 32347727       3414693       3414693   1108388   205818             5
# 32380527       3418470       3418470   1916142   206049             1
# 32380551       3418473       3418473    379732   206049             4
#
#           orders_day_of_week  order_time_hour  days_since_prior_order  \
# ...

# %%
#check max value
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %% [markdown]
# ### 2.5. Drop unwanted columns

# %%
# Drop unnecessary columns
ords_prods_merge = ords_prods_merge.drop(['Unnamed: 0.1', 'Unnamed: 0_x', '_merge', 'Unnamed: 0_y', 'match'], axis=1)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_hour  \
# 0   2539329        1             1                   2                8
# 1   2539329        1             1                   2                8
# 2   2539329        1             1                   2                8
# 3   2539329        1             1                   2                8
# 4   2539329        1             1                   2                8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# ## 3. Task
# ### 3.1. Change conditions of "busiest_day" column to "busiest_days"

# %% [markdown]
# 2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []
for value in ords_prods_merge["orders_day_of_week"]:
  if (value == 0 or value == 1):
    result.append("Busy day")
  elif (value == 4 or value == 3):
    result.append("Slow day")
  else:
    result.append("Regular day")

# %%
result
# Out:
# ['Regular day',
#  'Regular day',
#  'Regular day',
#  'Regular day',
#  'Regular day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Regular day',
#  'Regular day',
#  'Regular day',
#  'Regular day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Slow day',
#  'Regular day',
#  'Regular day',
#  'Regular day',
#  'Regular day',
# ...

# %%
ords_prods_merge['busiest_days'] = result

# %%
ords_prods_merge
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32404854   2977660   206209            13                   1
# 32404855   2977660   206209            13                   1
# 32404856   2977660   206209            13                   1
# 32404857   2977660   206209            13                   1
# 32404858   2977660   206209            13                   1
#
#           order_time_hour  days_since_prior_order  first_order  product_id  \
# 0                       8                     NaN         True         196
# ...

# %% [markdown]
# ### 3.2. Check accuracy of the new column

# %% [markdown]
# 3. Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regular day    12916111
# Busy day       11864412
# Slow day        7624336
# Name: count, dtype: int64

# %% [markdown]
# The values are accurate with the previous values for the days of the week and their orders count.

# %% [markdown]
# ### 3.3. Create new column "busiest_period_of_day"

# %% [markdown]
# 4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
ords_prods_merge['order_time_hour'].value_counts(dropna = False)
# Out:
# order_time_hour
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
result_2 = []
for value in ords_prods_merge["order_time_hour"]:
  if (value == 10 or value == 11 or value == 14 or value == 15 or value == 13 or value == 12 or value == 16 or value == 9):
    result_2.append("Most orders")
  elif (value == 17 or value == 8 or value == 18 or value == 19 or value == 20 or value == 7 or value == 21 or value == 22):
    result_2.append("Average orders")
  else:
    result_2.append("Fewest orders")

# %%
result_2
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
ords_prods_merge['busiest_period_of_day'] = result_2

# %%
ords_prods_merge
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32404854   2977660   206209            13                   1
# 32404855   2977660   206209            13                   1
# 32404856   2977660   206209            13                   1
# 32404857   2977660   206209            13                   1
# 32404858   2977660   206209            13                   1
#
#           order_time_hour  days_since_prior_order  first_order  product_id  \
# 0                       8                     NaN         True         196
# ...

# %% [markdown]
# ### 3.4. Show frequency of "busiest_period_of_day" columns

# %% [markdown]
# 5. Print the frequency for this new column.

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
# 6. Ensure your notebook is clean and structured and that your code is well commented.
#    Done.

# %% [markdown]
# ### 3.5. Export dataframe

# %% [markdown]
# 7. Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
# Export new dataframe
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_4_7.pkl'))
